# %%
import pandas as pd

# %%
Normal_data = pd.read_csv('../UNSW_NB15_NORMAL.csv', index_col=False)
Normal_data
# Out:
#             dur proto service state  spkts  dpkts  sbytes  dbytes  \
# 0      0.000011   udp       -   INT      2      0     496       0
# 1      0.000008   udp       -   INT      2      0    1762       0
# 2      0.000005   udp       -   INT      2      0    1068       0
# 3      0.000006   udp       -   INT      2      0     900       0
# 4      0.000010   udp       -   INT      2      0    2126       0
# ...         ...   ...     ...   ...    ...    ...     ...     ...
# 36995  0.000005   udp       -   INT      2      0     104       0
# 36996  1.106101   tcp       -   FIN     20      8   18062     354
# 36997  0.000000   arp       -   INT      1      0      46       0
# 36998  0.000000   arp       -   INT      1      0      46       0
# 36999  0.000009   udp       -   INT      2      0     104       0
#
#                 rate  sttl  ...  ct_dst_sport_ltm  ct_dst_src_ltm  \
# 0       90909.090200   254  ...                 1               2
# ...
